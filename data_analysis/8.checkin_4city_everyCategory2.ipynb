# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
checkin_phoenix = pd.read_csv('../dataset/Phoenix_c2c_count.csv', encoding='ISO-8859-1')
checkin_calgary = pd.read_csv('../dataset/Calgary_c2c_count.csv', encoding='ISO-8859-1')
checkin_newyork = pd.read_csv('../dataset/NewYork_c2c_count.csv', encoding='ISO-8859-1')
checkin_singapore= pd.read_csv('../dataset/Singapore_c2c_count.csv', encoding='ISO-8859-1')
print(checkin_phoenix.shape)
print(checkin_calgary.shape)
print(checkin_newyork.shape)
print(checkin_singapore.shape)
# Out:
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)

# %%
checkin_singapore
# Out:
#    Professional & Other Places2College & University  \
# 0                                              1171
#
#    College & University2Shop & Service  Shop & Service2Arts & Entertainment  \
# 0                                 1660                                 2519
#
#    Professional & Other Places2Shop & Service  \
# 0                                        4345
#
#    Professional & Other Places2Arts & Entertainment  \
# 0                                               780
#
#    Arts & Entertainment2Arts & Entertainment  \
# 0                                        890
#
#    Arts & Entertainment2College & University  \
# 0                                         73
#
#    Professional & Other Places2Nightlife Spot  \
# 0                                         491
#
#    Professional & Other Places2Professional & Other Places  \
# 0                                               4186
#
#    Arts & Entertainment2Outdoors & Recreation  ...  \
# ...

# %%
sum_phoenix = pd.to_numeric(checkin_phoenix.iloc[:,:].sum(axis=1), errors='ignore')
sum_calgary = pd.to_numeric(checkin_calgary.iloc[:,:].sum(axis=1), errors='ignore')
sum_newyork = pd.to_numeric(checkin_newyork.iloc[:,:].sum(axis=1), errors='ignore')
sum_singapore = pd.to_numeric(checkin_singapore.iloc[:,:].sum(axis=1), errors='ignore')

# %%
sum_phoenix[0]
# Out:
# 17410

# %%
checkin_phoenix = checkin_phoenix.div(sum_phoenix[0])
checkin_calgary = checkin_calgary.div(sum_calgary[0])
checkin_newyork = checkin_newyork.div(sum_newyork[0])
checkin_singapore = checkin_singapore.div(sum_singapore[0])
checkin_singapore
# Out:
#    Professional & Other Places2College & University  \
# 0                                          0.006508
#
#    College & University2Shop & Service  Shop & Service2Arts & Entertainment  \
# 0                             0.009226                                0.014
#
#    Professional & Other Places2Shop & Service  \
# 0                                    0.024148
#
#    Professional & Other Places2Arts & Entertainment  \
# 0                                          0.004335
#
#    Arts & Entertainment2Arts & Entertainment  \
# 0                                   0.004946
#
#    Arts & Entertainment2College & University  \
# 0                                   0.000406
#
#    Professional & Other Places2Nightlife Spot  \
# 0                                    0.002729
#
#    Professional & Other Places2Professional & Other Places  \
# 0                                           0.023264
#
#    Arts & Entertainment2Outdoors & Recreation  ...  \
# ...

# %%
checkin_phoenix = checkin_phoenix.sort_values(axis =1,by = [0],ascending = False)
checkin_calgary = checkin_calgary.sort_values(axis =1,by = [0],ascending = False)
checkin_newyork = checkin_newyork.sort_values(axis =1,by = [0],ascending = False)
checkin_singapore = checkin_singapore.sort_values(axis =1,by = [0],ascending = False)
checkin_singapore
# Out:
#    Travel & Transport2Travel & Transport  Shop & Service2Shop & Service  \
# 0                                0.08575                       0.072972
#
#    Travel & Transport2Shop & Service  Shop & Service2Food  \
# 0                           0.054182             0.053237
#
#    Travel & Transport2Food  Residence2Residence  Travel & Transport2Residence  \
# 0                 0.031746             0.030328                      0.027377
#
#    Food2Shop & Service  Shop & Service2Travel & Transport  \
# 0             0.026271                           0.025643
#
#    Professional & Other Places2Shop & Service  ...  Drink2Nightlife Spot  \
# 0                                    0.024148  ...               0.00115
#
#    Nightlife Spot2Professional & Other Places  \
# 0                                    0.001106
#
#    Outdoors & Recreation2College & University  \
# 0                                    0.001045
#
# ...

# %%
data= pd.DataFrame()
data = data.append(checkin_phoenix,ignore_index= True)
data = data.append(checkin_calgary,ignore_index= True)
data = data.append(checkin_newyork,ignore_index= True)
data = data.append(checkin_singapore,ignore_index= True)
data=data.fillna(0)
data.astype(int)
data.index = pd.Series(['Phoenix', 'Calgary','NewYork','Singapore'])
data
# Out:
#            Travel & Transport2Travel & Transport  \
# Phoenix                                 0.078978
# Calgary                                 0.054578
# NewYork                                 0.055683
# Singapore                               0.085750
#
#            Shop & Service2Shop & Service  Food2Shop & Service  \
# Phoenix                         0.072947             0.040379
# Calgary                         0.083676             0.032550
# NewYork                         0.030195             0.030120
# Singapore                       0.072972             0.026271
#
#            Shop & Service2Food  Shop & Service2Residence  Food2Food  \
# Phoenix               0.036186                  0.033199   0.031648
# Calgary               0.026138                  0.013645   0.020878
# NewYork               0.022206                  0.005894   0.056445
# Singapore             0.053237                  0.019852   0.022859
#
# ...

# %%
data = data.stack().unstack(0)
data
# Out:
#                                                      Phoenix   Calgary  \
# Travel & Transport2Travel & Transport               0.078978  0.054578
# Shop & Service2Shop & Service                       0.072947  0.083676
# Food2Shop & Service                                 0.040379  0.032550
# Shop & Service2Food                                 0.036186  0.026138
# Shop & Service2Residence                            0.033199  0.013645
# Food2Food                                           0.031648  0.020878
# Residence2Shop & Service                            0.030155  0.025316
# Residence2Residence                                 0.029581  0.018576
# Food2Residence                                      0.022458  0.007562
# Professional & Other Places2Professional & Othe...  0.021884  0.031070
# Professional & Other Places2Shop & Service          0.020965  0.034851
# Shop & Service2Professional & Other Places          0.020448  0.020878
# ...

# %%
pd.set_option('display.max_rows', None)
sort_data = data.sort_index(axis=0)
sort_data
# Out:
#                                                      Phoenix   Calgary  \
# Arts & Entertainment2Arts & Entertainment           0.009592  0.009206
# Arts & Entertainment2College & University           0.000804  0.000822
# Arts & Entertainment2Drink                          0.001493  0.002466
# Arts & Entertainment2Food                           0.010684  0.006247
# Arts & Entertainment2Nightlife Spot                 0.006146  0.002301
# Arts & Entertainment2Outdoors & Recreation          0.004997  0.006576
# Arts & Entertainment2Professional & Other Places    0.005055  0.005261
# Arts & Entertainment2Residence                      0.004652  0.001480
# Arts & Entertainment2Shop & Service                 0.007295  0.010357
# Arts & Entertainment2Travel & Transport             0.004021  0.002630
# College & University2Arts & Entertainment           0.000460  0.000329
# College & University2College & University           0.011488  0.003123
# ...

# %%
art = sort_data[:10]
print(art.shape)
art
# Out:
# (10, 4)
#                                                    Phoenix   Calgary  \
# Arts & Entertainment2Arts & Entertainment         0.009592  0.009206
# Arts & Entertainment2College & University         0.000804  0.000822
# Arts & Entertainment2Drink                        0.001493  0.002466
# Arts & Entertainment2Food                         0.010684  0.006247
# Arts & Entertainment2Nightlife Spot               0.006146  0.002301
# Arts & Entertainment2Outdoors & Recreation        0.004997  0.006576
# Arts & Entertainment2Professional & Other Places  0.005055  0.005261
# Arts & Entertainment2Residence                    0.004652  0.001480
# Arts & Entertainment2Shop & Service               0.007295  0.010357
# Arts & Entertainment2Travel & Transport           0.004021  0.002630
#
#                                                    NewYork  Singapore
# Arts & Entertainment2Arts & Entertainment         0.011779   0.004946
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(art, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
college = sort_data[10:20]
print(college.shape)
college
# Out:
# (10, 4)
#                                                    Phoenix   Calgary  \
# College & University2Arts & Entertainment         0.000460  0.000329
# College & University2College & University         0.011488  0.003123
# College & University2Drink                        0.002125  0.001151
# College & University2Food                         0.003159  0.001151
# College & University2Nightlife Spot               0.000632  0.000986
# College & University2Outdoors & Recreation        0.000804  0.000329
# College & University2Professional & Other Places  0.000862  0.001151
# College & University2Residence                    0.002068  0.000493
# College & University2Shop & Service               0.002929  0.000986
# College & University2Travel & Transport           0.000517  0.001151
#
#                                                    NewYork  Singapore
# College & University2Arts & Entertainment         0.000869   0.001828
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(college, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
drink = sort_data[20:30]
print(drink.shape)
drink
# Out:
# (10, 4)
#                                     Phoenix   Calgary   NewYork  Singapore
# Drink2Arts & Entertainment         0.001034  0.000658  0.002813   0.001245
# Drink2College & University         0.001953  0.000822  0.001333   0.000589
# Drink2Drink                        0.003848  0.006576  0.003192   0.002117
# Drink2Food                         0.004882  0.011179  0.009282   0.006069
# Drink2Nightlife Spot               0.001091  0.002795  0.002283   0.001150
# Drink2Outdoors & Recreation        0.001551  0.004439  0.004748   0.001339
# Drink2Professional & Other Places  0.003963  0.020385  0.006678   0.002734
# Drink2Residence                    0.002298  0.006247  0.001498   0.003396
# Drink2Shop & Service               0.007410  0.021371  0.007445   0.006736
# Drink2Travel & Transport           0.002814  0.002959  0.004382   0.004168

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(drink, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
food = sort_data[30:40]
print(food.shape)
food
# Out:
# (10, 4)
#                                    Phoenix   Calgary   NewYork  Singapore
# Food2Arts & Entertainment         0.012177  0.007069  0.014422   0.006936
# Food2College & University         0.003791  0.001151  0.002782   0.002912
# Food2Drink                        0.008788  0.008220  0.009304   0.006608
# Food2Food                         0.031648  0.020878  0.056445   0.022859
# Food2Nightlife Spot               0.010454  0.010028  0.022478   0.005246
# Food2Outdoors & Recreation        0.007524  0.006247  0.021988   0.005952
# Food2Professional & Other Places  0.017748  0.012165  0.017588   0.009904
# Food2Residence                    0.022458  0.007562  0.008970   0.014172
# Food2Shop & Service               0.040379  0.032550  0.030120   0.026271
# Food2Travel & Transport           0.012636  0.010028  0.020080   0.015534

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(food, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
nightlife = sort_data[40:50]
print(nightlife.shape)
nightlife
# Out:
# (10, 4)
#                                              Phoenix   Calgary   NewYork  \
# Nightlife Spot2Arts & Entertainment         0.004652  0.002466  0.006687
# Nightlife Spot2College & University         0.000574  0.000164  0.000999
# Nightlife Spot2Drink                        0.001723  0.003945  0.002987
# Nightlife Spot2Food                         0.012062  0.011343  0.022594
# Nightlife Spot2Nightlife Spot               0.015623  0.014467  0.023495
# Nightlife Spot2Outdoors & Recreation        0.002700  0.005096  0.008118
# Nightlife Spot2Professional & Other Places  0.004595  0.006411  0.005091
# Nightlife Spot2Residence                    0.005514  0.004603  0.003758
# Nightlife Spot2Shop & Service               0.007007  0.009535  0.008497
# Nightlife Spot2Travel & Transport           0.003676  0.003781  0.007249
#
#                                             Singapore
# Nightlife Spot2Arts & Entertainment          0.000478
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(nightlife, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
outdoor = sort_data[50:60]
print(outdoor.shape)
outdoor
# Out:
# (10, 4)
#                                                     Phoenix   Calgary  \
# Outdoors & Recreation2Arts & Entertainment         0.003906  0.004274
# Outdoors & Recreation2College & University         0.000976  0.000329
# Outdoors & Recreation2Drink                        0.003619  0.005754
# Outdoors & Recreation2Food                         0.009592  0.007891
# Outdoors & Recreation2Nightlife Spot               0.002929  0.002466
# Outdoors & Recreation2Outdoors & Recreation        0.012062  0.012823
# Outdoors & Recreation2Professional & Other Places  0.008960  0.012987
# Outdoors & Recreation2Residence                    0.011028  0.007069
# Outdoors & Recreation2Shop & Service               0.013498  0.017097
# Outdoors & Recreation2Travel & Transport           0.009248  0.005425
#
#                                                     NewYork  Singapore
# Outdoors & Recreation2Arts & Entertainment         0.008560   0.002379
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(outdoor, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
professional = sort_data[60:70]
print(professional.shape)
professional
# Out:
# (10, 4)
#                                                      Phoenix   Calgary  \
# Professional & Other Places2Arts & Entertainment    0.003906  0.001808
# Professional & Other Places2College & University    0.000976  0.000822
# Professional & Other Places2Drink                   0.003561  0.012001
# Professional & Other Places2Food                    0.016427  0.022357
# Professional & Other Places2Nightlife Spot          0.003963  0.005261
# Professional & Other Places2Outdoors & Recreation   0.004480  0.006740
# Professional & Other Places2Professional & Othe...  0.021884  0.031070
# Professional & Other Places2Residence               0.008041  0.011836
# Professional & Other Places2Shop & Service          0.020965  0.034851
# Professional & Other Places2Travel & Transport      0.008386  0.019070
#
#                                                      NewYork  Singapore
# Professional & Other Places2Arts & Entertainment    0.005131   0.004335
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(professional, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
residence = sort_data[70:80]
print(residence.shape)
residence
# Out:
# (10, 4)
#                                         Phoenix   Calgary   NewYork  Singapore
# Residence2Arts & Entertainment         0.002814  0.001973  0.002546   0.002129
# Residence2College & University         0.004423  0.000658  0.002064   0.002757
# Residence2Drink                        0.004538  0.014302  0.002323   0.001862
# Residence2Food                         0.015451  0.009206  0.010334   0.008759
# Residence2Nightlife Spot               0.004538  0.003452  0.002599   0.001389
# Residence2Outdoors & Recreation        0.009362  0.008713  0.008876   0.003779
# Residence2Professional & Other Places  0.015738  0.018248  0.008043   0.007392
# Residence2Residence                    0.029581  0.018576  0.010472   0.030328
# Residence2Shop & Service               0.030155  0.025316  0.009790   0.012599
# Residence2Travel & Transport           0.010339  0.013316  0.011877   0.015100

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(residence, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
shop = sort_data[80:90]
print(shop.shape)
shop
# Out:
# (10, 4)
#                                              Phoenix   Calgary   NewYork  \
# Shop & Service2Arts & Entertainment         0.006088  0.005425  0.005635
# Shop & Service2College & University         0.001838  0.002137  0.001485
# Shop & Service2Drink                        0.007984  0.017097  0.004801
# Shop & Service2Food                         0.036186  0.026138  0.022206
# Shop & Service2Nightlife Spot               0.007237  0.007069  0.005287
# Shop & Service2Outdoors & Recreation        0.009075  0.010028  0.012140
# Shop & Service2Professional & Other Places  0.020448  0.020878  0.008323
# Shop & Service2Residence                    0.033199  0.013645  0.005894
# Shop & Service2Shop & Service               0.072947  0.083676  0.030195
# Shop & Service2Travel & Transport           0.012636  0.013151  0.010142
#
#                                             Singapore
# Shop & Service2Arts & Entertainment          0.014000
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(shop, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
travel = sort_data[90:100]
print(travel.shape)
travel
# Out:
# (10, 4)
#                                                  Phoenix   Calgary   NewYork  \
# Travel & Transport2Arts & Entertainment         0.003848  0.008055  0.008087
# Travel & Transport2College & University         0.001091  0.003781  0.003567
# Travel & Transport2Drink                        0.005629  0.010028  0.007017
# Travel & Transport2Food                         0.017346  0.011672  0.026032
# Travel & Transport2Nightlife Spot               0.005457  0.007069  0.006714
# Travel & Transport2Outdoors & Recreation        0.012062  0.008713  0.020503
# Travel & Transport2Professional & Other Places  0.009994  0.016768  0.019224
# Travel & Transport2Residence                    0.010626  0.005754  0.009220
# Travel & Transport2Shop & Service               0.015623  0.025316  0.019754
# Travel & Transport2Travel & Transport           0.078978  0.054578  0.055683
#
#                                                 Singapore
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(travel, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
#################################

# %%
toFood = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toFood
for index1,val1 in data.iterrows():
    if index1.find("2Food") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toFood.loc['%s'%(index1)] = val1.tolist()
toFood
plt.figure(figsize=(9, 9))
sns.heatmap(toFood, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toShop = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toShop
for index1,val1 in data.iterrows():
    if index1.find("2Shop & Service") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toShop.loc['%s'%(index1)] = val1.tolist()
toShop
plt.figure(figsize=(9, 9))
sns.heatmap(toShop, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toDrink = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toDrink
for index1,val1 in data.iterrows():
    if index1.find("2Drink") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toDrink.loc['%s'%(index1)] = val1.tolist()
toDrink
plt.figure(figsize=(9, 9))
sns.heatmap(toDrink, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toTravel = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toTravel
for index1,val1 in data.iterrows():
    if index1.find("2Travel & Transport") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toTravel.loc['%s'%(index1)] = val1.tolist()
toTravel
plt.figure(figsize=(9, 9))
sns.heatmap(toTravel, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toPro = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toPro
for index1,val1 in data.iterrows():
    if index1.find("2Professional & Other Places") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toPro.loc['%s'%(index1)] = val1.tolist()
toPro
plt.figure(figsize=(9, 9))
sns.heatmap(toPro, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toCollege = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toCollege
for index1,val1 in data.iterrows():
    if index1.find("2College & University") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toCollege.loc['%s'%(index1)] = val1.tolist()
toCollege
plt.figure(figsize=(9, 9))
sns.heatmap(toCollege, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toNight = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toNight
for index1,val1 in data.iterrows():
    if index1.find("2Nightlife Spot") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toNight.loc['%s'%(index1)] = val1.tolist()
toNight
plt.figure(figsize=(9, 9))
sns.heatmap(toNight, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toResidence = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toResidence
for index1,val1 in data.iterrows():
    if index1.find("2Residence") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toResidence.loc['%s'%(index1)] = val1.tolist()
toResidence
plt.figure(figsize=(9, 9))
sns.heatmap(toResidence, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toArt = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toArt
for index1,val1 in data.iterrows():
    if index1.find("2Arts & Entertainment") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toArt.loc['%s'%(index1)] = val1.tolist()
toArt
plt.figure(figsize=(9, 9))
sns.heatmap(toArt, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})

# %%
toOutdoors = pd.DataFrame(columns=['Phoenix','Calgary','NewYork',"Singapore"])
toOutdoors
for index1,val1 in data.iterrows():
    if index1.find("2Outdoors & Recreation") == -1:
        continue
    else:
        #print( "Found 'is' in the string.")
        #print(val1.tolist())
        #toCategory = toCategory.append([{'Phoenix': val1[0], 'Calgary': val1[1], 'NewYork': val1[2], 'Singapore': val1[3]}], ignore_index=True)
        toOutdoors.loc['%s'%(index1)] = val1.tolist()
toOutdoors
plt.figure(figsize=(9, 9))
sns.heatmap(toOutdoors, square=True, annot=True, fmt='0.4f',annot_kws={'size':9,})
